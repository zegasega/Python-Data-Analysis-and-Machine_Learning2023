# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
# y = mx + mx + b
#y tahmin etmke istediğimiz şey

#buradaki mx saıyısı tahmin etmek istediğmiz datayı etkileyen faktörler

# %%
df = pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
y = df[["Marks"]]
x = df[["number_courses","time_study"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
#veri az olduğu için train test yapmıyorum

# %%
#sklearn.linear_model.LinearRegression()
l = LinearRegression()

model = l.fit(x,y)

# %%
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
model.predict([[4,4]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[21.59657189]])

# %%
df["Marks"].max()
# Out:
# 55.299

# %%
model.predict([[4,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[53.99164461]])

# %%
model.score(x,y)
# Out:
# 0.9403656320238896
