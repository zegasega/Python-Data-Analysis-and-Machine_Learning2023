# %%
import numpy as np

# %% [markdown]
# **numpy array**

# %%
liste = [20,30,40]

type(liste)
# Out:
# list

# %%
np.array(liste)
# Out:
# array([20, 30, 40])

# %%
type(np.array(liste))
# Out:
# numpy.ndarray

# %%
matrixlist = [[10,20,30],[20,30,40],[30,40,50]]

# %%
type(matrixlist)
# Out:
# list

# %%
np.array(matrixlist)
# Out:
# array([[10, 20, 30],
#        [20, 30, 40],
#        [30, 40, 50]])

# %%
type(np.array(matrixlist))
# Out:
# numpy.ndarray
