# %%
# Part 2: Add API data

## We now want to show each customer’s account volume in the respective currency too.

## Please use an api of your choice to get the conversion rates for every day (e.g. https://openexchangerates.org/ offers a free version, with some limits) and add the information about the amounts in local currency to the data set.

## app_id=c92e9bfec2584ff0848965f86681ec37
import requests
import pandas as pd
from datetime import datetime
