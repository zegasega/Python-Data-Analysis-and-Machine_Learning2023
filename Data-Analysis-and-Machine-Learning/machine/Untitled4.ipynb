# %%
import requests

# %%
rsp = requests.get('https://api.currencyapi.com/v3/latest?apikey=cur_live_8YEOX82NShzpChYCk9sAMHumNcH8rMu59cnWIeR7').json()
rsp
# Out:
# {'meta': {'last_updated_at': '2023-08-05T23:59:59Z'},
#  'data': {'ADA': {'code': 'ADA', 'value': 3.3975091277},
#   'AED': {'code': 'AED', 'value': 3.6730504969},
#   'AFN': {'code': 'AFN', 'value': 85.2250406966},
#   'ALL': {'code': 'ALL', 'value': 94.0048123792},
#   'AMD': {'code': 'AMD', 'value': 386.7652514683},
#   'ANG': {'code': 'ANG', 'value': 1.7872002146},
#   'AOA': {'code': 'AOA', 'value': 826.3818091533},
#   'ARB': {'code': 'ARB', 'value': 0.8784004358},
#   'ARS': {'code': 'ARS', 'value': 279.3609073126},
#   'AUD': {'code': 'AUD', 'value': 1.5226402518},
#   'AVAX': {'code': 'AVAX', 'value': 0.0802618279},
#   'AWG': {'code': 'AWG', 'value': 1.79},
#   'AZN': {'code': 'AZN', 'value': 1.7},
#   'BAM': {'code': 'BAM', 'value': 1.7801101906},
#   'BBD': {'code': 'BBD', 'value': 2},
#   'BDT': {'code': 'BDT', 'value': 109.1179599431},
#   'BGN': {'code': 'BGN', 'value': 1.7862602408},
#   'BHD': {'code': 'BHD', 'value': 0.376},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(rsp)
df
# Out:
#                                  meta  \
# last_updated_at  2023-08-05T23:59:59Z
# ADA                               NaN
# AED                               NaN
# AFN                               NaN
# ALL                               NaN
# ...                               ...
# YER                               NaN
# ZAR                               NaN
# ZMK                               NaN
# ZMW                               NaN
# ZWL                               NaN
#
#                                                       data
# last_updated_at                                        NaN
# ADA                 {'code': 'ADA', 'value': 3.3975091277}
# AED                 {'code': 'AED', 'value': 3.6730504969}
# AFN                {'code': 'AFN', 'value': 85.2250406966}
# ALL                {'code': 'ALL', 'value': 94.0048123792}
# ...                                                    ...
# YER               {'code': 'YER', 'value': 249.9372758754}
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                                  meta  \
# last_updated_at  2023-08-05T23:59:59Z
# ADA                               NaN
# AED                               NaN
# AFN                               NaN
# ALL                               NaN
# ...                               ...
# YER                               NaN
# ZAR                               NaN
# ZMK                               NaN
# ZMW                               NaN
# ZWL                               NaN
#
#                                                       data
# last_updated_at                                        NaN
# ADA                 {'code': 'ADA', 'value': 3.3975091277}
# AED                 {'code': 'AED', 'value': 3.6730504969}
# AFN                {'code': 'AFN', 'value': 85.2250406966}
# ALL                {'code': 'ALL', 'value': 94.0048123792}
# ...                                                    ...
# ...
