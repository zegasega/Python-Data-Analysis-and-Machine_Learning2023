# %%
import pandas as pd

# %%
df = pd.read_csv('covid19tr.csv')
df.head(10)
# Out:
#          date  test  case  death  recovered
# 0  2020-03-13     0     5    NaN        NaN
# 1  2020-03-14     0     6    NaN        NaN
# 2  2020-03-15     0     7    NaN        NaN
# 3  2020-03-16     0    31    NaN        NaN
# 4  2020-03-17     0    49    1.0        NaN
# 5  2020-03-18     0    93    1.0        NaN
# 6  2020-03-19  1981   168    2.0        NaN
# 7  2020-03-20  3656   311    5.0        NaN
# 8  2020-03-21  2970   277   12.0        NaN
# 9  2020-03-22  1738   289    9.0        NaN

# %%
df.tail()
# Out:
#            date   test  case  death  recovered
# 156  2020-08-16  65956  1192   19.0      997.0
# 157  2020-08-17  74846  1233   22.0     1002.0
# 158  2020-08-18  82318  1263   20.0      942.0
# 159  2020-08-19  87223  1303   23.0     1002.0
# 160  2020-08-20  92301  1412   19.0      882.0

# %%
df.info
# Out:
# <bound method DataFrame.info of            date   test  case  death  recovered
# 0    2020-03-13      0     5    NaN        NaN
# 1    2020-03-14      0     6    NaN        NaN
# 2    2020-03-15      0     7    NaN        NaN
# 3    2020-03-16      0    31    NaN        NaN
# 4    2020-03-17      0    49    1.0        NaN
# ..          ...    ...   ...    ...        ...
# 156  2020-08-16  65956  1192   19.0      997.0
# 157  2020-08-17  74846  1233   22.0     1002.0
# 158  2020-08-18  82318  1263   20.0      942.0
# 159  2020-08-19  87223  1303   23.0     1002.0
# 160  2020-08-20  92301  1412   19.0      882.0
#
# [161 rows x 5 columns]>

# %%
df.columns
# Out:
# Index(['date', 'test', 'case', 'death', 'recovered'], dtype='object')

# %%
df.isnull().sum()
# Out:
# date          0
# test          0
# case          0
# death         4
# recovered    13
# dtype: int64

# %%
df.dropna(subset['recovered'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9a5a8401308c> in <cell line: 1>()
# ----> 1 df.dropna(subset['recovered'],inplace=True)
#
# NameError: name 'subset' is not defined

# %%
# Out:
# <bound method DataFrame.dropna of            date   test  case  death  recovered
# 0    2020-03-13      0     5    NaN        NaN
# 1    2020-03-14      0     6    NaN        NaN
# 2    2020-03-15      0     7    NaN        NaN
# 3    2020-03-16      0    31    NaN        NaN
# 4    2020-03-17      0    49    1.0        NaN
# ..          ...    ...   ...    ...        ...
# 156  2020-08-16  65956  1192   19.0      997.0
# 157  2020-08-17  74846  1233   22.0     1002.0
# 158  2020-08-18  82318  1263   20.0      942.0
# 159  2020-08-19  87223  1303   23.0     1002.0
# 160  2020-08-20  92301  1412   19.0      882.0
#
# [161 rows x 5 columns]>
