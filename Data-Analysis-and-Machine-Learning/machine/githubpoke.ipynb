# %%
import pandas as pd

# %%
df = pd.read_csv("Pokemon_Dataset.csv")

# %%
df.head()
# Out:
#    Number        Name  Type1   Type2  Total  HP  Attack  Defense  SpAtk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49     65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63     80
# 2       3    Venusaur  Grass  Poison    525  80      82       83    100
# 3       4  Charmander   Fire     NaN    309  39      52       43     60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58     80
#
#    SpDef  Speed
# 0     65     45
# 1     80     60
# 2    100     80
# 3     50     65
# 4     65     80

# %%
df.tail()
# Out:
#      Number        Name    Type1    Type2  Total  HP  Attack  Defense  SpAtk  \
# 195     196      Espeon  Psychic      NaN    525  65      65       60    130
# 196     197     Umbreon     Dark      NaN    525  95      65      110     60
# 197     198     Murkrow     Dark   Flying    405  60      85       42     85
# 198     199    Slowking    Water  Psychic    490  95      75       80    100
# 199     200  Misdreavus    Ghost      NaN    435  60      60       60     85
#
#      SpDef  Speed
# 195     95    110
# 196    130     65
# 197     42     91
# 198    110     30
# 199     85     85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Number   200 non-null    int64
#  1   Name     200 non-null    object
#  2   Type1    200 non-null    object
#  3   Type2    90 non-null     object
#  4   Total    200 non-null    int64
#  5   HP       200 non-null    int64
#  6   Attack   200 non-null    int64
#  7   Defense  200 non-null    int64
#  8   SpAtk    200 non-null    int64
#  9   SpDef    200 non-null    int64
#  10  Speed    200 non-null    int64
# dtypes: int64(8), object(3)
# memory usage: 17.3+ KB

# %%
df.shape
# Out:
# (200, 11)

# %%
df.columns
# Out:
# Index(['Number', 'Name', 'Type1', 'Type2', 'Total', 'HP', 'Attack', 'Defense',
#        'SpAtk', 'SpDef', 'Speed'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
df.style.hide_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-046e9c3a6dbb> in <cell line: 1>()
# ----> 1 df.style.hide_index()
#
# AttributeError: 'Styler' object has no attribute 'style'
